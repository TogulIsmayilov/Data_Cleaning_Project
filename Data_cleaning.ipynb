# %%
import pandas as pd

# %%
data=pd.read_csv('amazon_sales_data 2025.csv')

# %%
data
# Out:
#     Order ID      Date        Product     Category  Price  Quantity  \
# 0    ORD0001  14-03-25  Running Shoes     Footwear     60         3
# 1    ORD0002  20-03-25     Headphones  Electronics    100         4
# 2    ORD0003  15-02-25  Running Shoes     Footwear     60         2
# 3    ORD0004  19-02-25  Running Shoes     Footwear     60         3
# 4    ORD0005  10-03-25     Smartwatch  Electronics    150         3
# ..       ...       ...            ...          ...    ...       ...
# 245  ORD0246  17-03-25        T-Shirt     Clothing     20         2
# 246  ORD0247  30-03-25          Jeans     Clothing     40         1
# 247  ORD0248  05-03-25        T-Shirt     Clothing     20         2
# 248  ORD0249  08-03-25     Smartwatch  Electronics    150         3
# 249  ORD0250  19-02-25     Smartphone  Electronics    500         4
#
#      Total Sales  Customer Name Customer Location Payment Method     Status
# ...

# %%
data['Product']=data['Product'].astype('category')

# %%
data['Date'].dtype
# Out:
# dtype('O')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           250 non-null    object
#  1   Date               250 non-null    object
#  2   Product            250 non-null    category
#  3   Category           250 non-null    object
#  4   Price              250 non-null    int64
#  5   Quantity           250 non-null    int64
#  6   Total Sales        250 non-null    int64
#  7   Customer Name      250 non-null    object
#  8   Customer Location  250 non-null    object
#  9   Payment Method     250 non-null    object
#  10  Status             250 non-null    object
# dtypes: category(1), int64(3), object(7)
# memory usage: 20.3+ KB

# %%
data.describe()
# Out:
#              Price    Quantity  Total Sales
# count   250.000000  250.000000   250.000000
# mean    343.580000    2.856000   975.380000
# std     380.635808    1.429489  1252.112254
# min      15.000000    1.000000    15.000000
# 25%      40.000000    2.000000   100.000000
# 50%     150.000000    3.000000   400.000000
# 75%     600.000000    4.000000  1500.000000
# max    1200.000000    5.000000  6000.000000

# %%
data.isnull().sum()
# Out:
# Order ID             0
# Date                 0
# Product              0
# Category             0
# Price                0
# Quantity             0
# Total Sales          0
# Customer Name        0
# Customer Location    0
# Payment Method       0
# Status               0
# dtype: int64

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop(columns=['Payment Method','Status'],inplace=True)

# %%
data
# Out:
#     Order ID      Date        Product     Category  Price  Quantity  \
# 0    ORD0001  14-03-25  Running Shoes     Footwear     60         3
# 1    ORD0002  20-03-25     Headphones  Electronics    100         4
# 2    ORD0003  15-02-25  Running Shoes     Footwear     60         2
# 3    ORD0004  19-02-25  Running Shoes     Footwear     60         3
# 4    ORD0005  10-03-25     Smartwatch  Electronics    150         3
# ..       ...       ...            ...          ...    ...       ...
# 245  ORD0246  17-03-25        T-Shirt     Clothing     20         2
# 246  ORD0247  30-03-25          Jeans     Clothing     40         1
# 247  ORD0248  05-03-25        T-Shirt     Clothing     20         2
# 248  ORD0249  08-03-25     Smartwatch  Electronics    150         3
# 249  ORD0250  19-02-25     Smartphone  Electronics    500         4
#
#      Total Sales  Customer Name Customer Location Payment Method     Status  \
# ...

# %%
data['Test']=data['Payment Method'].replace({'Debit Card':'Kart','Amazon Pay':'Amazon','Credit Card':'Kredit kart'})

# %%
data.index = range(1,len(data)+1)

# %%
top_5_sales=data.sort_values('Total Sales',ascending=False).drop_duplicates(subset=['Customer Location']).head(5)
five_sales=data.sort_values('Total Sales',ascending=True).drop_duplicates(subset=['Customer Name'])

# %%
top_5_sales
# Out:
#     Order ID      Date       Product         Category  Price  Quantity  \
# 126  ORD0126  04-02-25  Refrigerator  Home Appliances   1200         5
# 93   ORD0093  06-03-25  Refrigerator  Home Appliances   1200         5
# 69   ORD0069  25-02-25  Refrigerator  Home Appliances   1200         4
# 74   ORD0074  25-03-25  Refrigerator  Home Appliances   1200         4
# 155  ORD0155  05-02-25  Refrigerator  Home Appliances   1200         4
#
#      Total Sales  Customer Name Customer Location
# 126         6000  Olivia Wilson           Chicago
# 93          6000      David Lee            Denver
# 69          4800      David Lee            Boston
# 74          4800     Jane Smith            Dallas
# 155         4800  Sophia Miller           Seattle

# %%
top_5_sales.index = range(1,len(top_5_sales)+1)
five_sales.index = range(1,len(five_sales)+1)

# %%
import matplotlib.pyplot as plt

plt.barh(top_5_sales['Customer Location'],top_5_sales['Total Sales'],color='midnightblue')
plt.title('Ən çox satış edənlər')
plt.xticks(rotation=45)
plt.xlabel('Names')
plt.ylabel('Total Sales')
plt.show()

# %%
five_sales
# Out:
#    Order ID      Date  Product  Category  Price  Quantity  Total Sales  \
# 1   ORD0234  08-03-25     Book     Books     15         1           15
# 2   ORD0188  14-02-25     Book     Books     15         1           15
# 3   ORD0033  04-02-25     Book     Books     15         1           15
# 4   ORD0051  19-02-25     Book     Books     15         1           15
# 5   ORD0165  14-03-25     Book     Books     15         1           15
# 6   ORD0070  10-03-25     Book     Books     15         1           15
# 7   ORD0176  27-03-25     Book     Books     15         1           15
# 8   ORD0027  07-02-25  T-Shirt  Clothing     20         1           20
# 9   ORD0185  22-03-25  T-Shirt  Clothing     20         1           20
# 10  ORD0225  11-03-25    Jeans  Clothing     40         1           40
#
#     Customer Name Customer Location
# 1      Jane Smith             Miami
# 2        John Doe            Boston
# 3   Olivia Wilson          New York
# 4      Emma Clark           Houston
# ...

# %%
import matplotlib.pyplot as plt

plt.bar(five_sales['Customer Name'],five_sales['Total Sales'],color='midnightblue')
plt.title('Ən az satış edənlər')
plt.xticks(rotation=45)
plt.xlabel('Names')
plt.ylabel('Total Sales')
# Out:
# Text(0, 0.5, 'Total Sales')

# %%
data
# Out:
#     Order ID      Date        Product     Category  Price  Quantity  \
# 1    ORD0001  14-03-25  Running Shoes     Footwear     60         3
# 2    ORD0002  20-03-25     Headphones  Electronics    100         4
# 3    ORD0003  15-02-25  Running Shoes     Footwear     60         2
# 4    ORD0004  19-02-25  Running Shoes     Footwear     60         3
# 5    ORD0005  10-03-25     Smartwatch  Electronics    150         3
# ..       ...       ...            ...          ...    ...       ...
# 246  ORD0246  17-03-25        T-Shirt     Clothing     20         2
# 247  ORD0247  30-03-25          Jeans     Clothing     40         1
# 248  ORD0248  05-03-25        T-Shirt     Clothing     20         2
# 249  ORD0249  08-03-25     Smartwatch  Electronics    150         3
# 250  ORD0250  19-02-25     Smartphone  Electronics    500         4
#
#      Total Sales  Customer Name Customer Location
# 1            180     Emma Clark          New York
# ...

# %%
new_customers=data.sort_values('Date',ascending=False)[['Date','Category','Total Sales','Customer Location']].drop_duplicates(subset=['Date']).head(5)
new_customers.index=range(1,len(new_customers)+1)
new_customers
# Out:
#        Date         Category  Total Sales Customer Location
# 1  31-03-25  Home Appliances         2400            Dallas
# 2  30-03-25      Electronics          450          New York
# 3  29-03-25         Clothing          200            Dallas
# 4  28-03-25      Electronics         2400             Miami
# 5  28-02-25         Clothing          160           Seattle

# %%
import matplotlib.pyplot as plt

plt.pie(new_customers['Total Sales'],labels=new_customers['Customer Location'],autopct='%1.1f%%',startangle=140)
plt.title('New Customers')
plt.show()

# %%
data
# Out:
#     Order ID      Date        Product     Category  Price  Quantity  \
# 1    ORD0001  14-03-25  Running Shoes     Footwear     60         3
# 2    ORD0002  20-03-25     Headphones  Electronics    100         4
# 3    ORD0003  15-02-25  Running Shoes     Footwear     60         2
# 4    ORD0004  19-02-25  Running Shoes     Footwear     60         3
# 5    ORD0005  10-03-25     Smartwatch  Electronics    150         3
# ..       ...       ...            ...          ...    ...       ...
# 246  ORD0246  17-03-25        T-Shirt     Clothing     20         2
# 247  ORD0247  30-03-25          Jeans     Clothing     40         1
# 248  ORD0248  05-03-25        T-Shirt     Clothing     20         2
# 249  ORD0249  08-03-25     Smartwatch  Electronics    150         3
# 250  ORD0250  19-02-25     Smartphone  Electronics    500         4
#
#      Total Sales  Customer Name Customer Location
# 1            180     Emma Clark          New York
# ...

# %%
groupby_category=data.groupby('Category')['Total Sales'].sum().reset_index()
groupby_category.sort_values('Total Sales',ascending=False,inplace=True)
groupby_category.index=range(1,len(groupby_category)+1)

# %%
groupby_category
# Out:
#           Category  Total Sales
# 1      Electronics       129950
# 2  Home Appliances       105000
# 3         Footwear         4320
# 4         Clothing         3540
# 5            Books         1035

# %%
groupby_category2=data.groupby('Category')['Price'].min().reset_index()
groupby_category2
# Out:
#           Category  Price
# 0            Books     15
# 1         Clothing     20
# 2      Electronics    100
# 3         Footwear     60
# 4  Home Appliances    600

# %%
groupby_category2['Test1']=groupby_category2['Price'].apply(lambda x:'High' if x>150 else ('Medium' if x>=50 and x<=100 else'Low'))
groupby_category2.sort_values('Price',ascending=False,inplace=True)

# %%
groupby_category2
# Out:
#           Category  Price   Test1
# 4  Home Appliances    600    High
# 2      Electronics    100  Medium
# 3         Footwear     60  Medium
# 1         Clothing     20     Low
# 0            Books     15     Low

# %%
data.set_index('Customer Name',inplace=True)

# %%
data
# Out:
#               Order ID      Date        Product     Category  Price  Quantity  \
# Customer Name
# Emma Clark     ORD0001  14-03-25  Running Shoes     Footwear     60         3
# Emily Johnson  ORD0002  20-03-25     Headphones  Electronics    100         4
# John Doe       ORD0003  15-02-25  Running Shoes     Footwear     60         2
# Olivia Wilson  ORD0004  19-02-25  Running Shoes     Footwear     60         3
# Emma Clark     ORD0005  10-03-25     Smartwatch  Electronics    150         3
# ...                ...       ...            ...          ...    ...       ...
# Daniel Harris  ORD0246  17-03-25        T-Shirt     Clothing     20         2
# Sophia Miller  ORD0247  30-03-25          Jeans     Clothing     40         1
# Chris White    ORD0248  05-03-25        T-Shirt     Clothing     20         2
# Emily Johnson  ORD0249  08-03-25     Smartwatch  Electronics    150         3
# Emily Johnson  ORD0250  19-02-25     Smartphone  Electronics    500         4
#
# ...

# %%
data[(data['Category']=='Books') & (data['Customer Location']=='New York')]
# Out:
#               Order ID      Date Product Category  Price  Quantity  \
# Customer Name
# Olivia Wilson  ORD0033  04-02-25    Book    Books     15         1
# David Lee      ORD0165  14-03-25    Book    Books     15         1
#
#                Total Sales Customer Location
# Customer Name
# Olivia Wilson           15          New York
# David Lee               15          New York

# %%
data.query("Category=='Books' and `Customer Location`=='New York'")
# Out:
#               Order ID      Date Product Category  Price  Quantity  \
# Customer Name
# Olivia Wilson  ORD0033  04-02-25    Book    Books     15         1
# David Lee      ORD0165  14-03-25    Book    Books     15         1
#
#                Total Sales Customer Location
# Customer Name
# Olivia Wilson           15          New York
# David Lee               15          New York

# %%
data
# Out:
#               Order ID      Date        Product     Category  Price  Quantity  \
# Customer Name
# Emma Clark     ORD0001  14-03-25  Running Shoes     Footwear     60         3
# Emily Johnson  ORD0002  20-03-25     Headphones  Electronics    100         4
# John Doe       ORD0003  15-02-25  Running Shoes     Footwear     60         2
# Olivia Wilson  ORD0004  19-02-25  Running Shoes     Footwear     60         3
# Emma Clark     ORD0005  10-03-25     Smartwatch  Electronics    150         3
# ...                ...       ...            ...          ...    ...       ...
# Daniel Harris  ORD0246  17-03-25        T-Shirt     Clothing     20         2
# Sophia Miller  ORD0247  30-03-25          Jeans     Clothing     40         1
# Chris White    ORD0248  05-03-25        T-Shirt     Clothing     20         2
# Emily Johnson  ORD0249  08-03-25     Smartwatch  Electronics    150         3
# Emily Johnson  ORD0250  19-02-25     Smartphone  Electronics    500         4
#
# ...

# %%
data.rename(columns={'Date':'Tarix','Product':'Məhsul','Category':'Kateqoriya'},inplace=True)

# %%
data
# Out:
#               Order ID     Tarix         Məhsul   Kateqoriya  Price  Quantity  \
# Customer Name
# Emma Clark     ORD0001  14-03-25  Running Shoes     Footwear     60         3
# Emily Johnson  ORD0002  20-03-25     Headphones  Electronics    100         4
# John Doe       ORD0003  15-02-25  Running Shoes     Footwear     60         2
# Olivia Wilson  ORD0004  19-02-25  Running Shoes     Footwear     60         3
# Emma Clark     ORD0005  10-03-25     Smartwatch  Electronics    150         3
# ...                ...       ...            ...          ...    ...       ...
# Daniel Harris  ORD0246  17-03-25        T-Shirt     Clothing     20         2
# Sophia Miller  ORD0247  30-03-25          Jeans     Clothing     40         1
# Chris White    ORD0248  05-03-25        T-Shirt     Clothing     20         2
# Emily Johnson  ORD0249  08-03-25     Smartwatch  Electronics    150         3
# Emily Johnson  ORD0250  19-02-25     Smartphone  Electronics    500         4
#
# ...

# %%
data.groupby(['Kateqoriya','Məhsul']).agg({'Total Sales':['mean','max']})
# Out:
# C:\Users\TOGRUL\AppData\Local\Temp\ipykernel_20452\3067819330.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby(['Kateqoriya','Məhsul']).agg({'Total Sales':['mean','max']})
#                                  Total Sales
#                                         mean     max
# Kateqoriya      Məhsul
# Books           Book               41.400000    75.0
#                 Headphones               NaN     NaN
#                 Jeans                    NaN     NaN
#                 Laptop                   NaN     NaN
#                 Refrigerator             NaN     NaN
#                 Running Shoes            NaN     NaN
#                 Smartphone               NaN     NaN
#                 Smartwatch               NaN     NaN
# ...

# %%
data
# Out:
#               Order ID     Tarix         Məhsul   Kateqoriya  Price  Quantity  \
# Customer Name
# Emma Clark     ORD0001  14-03-25  Running Shoes     Footwear     60         3
# Emily Johnson  ORD0002  20-03-25     Headphones  Electronics    100         4
# John Doe       ORD0003  15-02-25  Running Shoes     Footwear     60         2
# Olivia Wilson  ORD0004  19-02-25  Running Shoes     Footwear     60         3
# Emma Clark     ORD0005  10-03-25     Smartwatch  Electronics    150         3
# ...                ...       ...            ...          ...    ...       ...
# Daniel Harris  ORD0246  17-03-25        T-Shirt     Clothing     20         2
# Sophia Miller  ORD0247  30-03-25          Jeans     Clothing     40         1
# Chris White    ORD0248  05-03-25        T-Shirt     Clothing     20         2
# Emily Johnson  ORD0249  08-03-25     Smartwatch  Electronics    150         3
# Emily Johnson  ORD0250  19-02-25     Smartphone  Electronics    500         4
#
# ...

# %%
data.set_index('Customer Name',inplace=True)

# %%
data
# Out:
#               Order ID      Date        Product     Category  Price  Quantity  \
# Customer Name
# Emma Clark     ORD0001  14-03-25  Running Shoes     Footwear     60         3
# Emily Johnson  ORD0002  20-03-25     Headphones  Electronics    100         4
# John Doe       ORD0003  15-02-25  Running Shoes     Footwear     60         2
# Olivia Wilson  ORD0004  19-02-25  Running Shoes     Footwear     60         3
# Emma Clark     ORD0005  10-03-25     Smartwatch  Electronics    150         3
# ...                ...       ...            ...          ...    ...       ...
# Daniel Harris  ORD0246  17-03-25        T-Shirt     Clothing     20         2
# Sophia Miller  ORD0247  30-03-25          Jeans     Clothing     40         1
# Chris White    ORD0248  05-03-25        T-Shirt     Clothing     20         2
# Emily Johnson  ORD0249  08-03-25     Smartwatch  Electronics    150         3
# Emily Johnson  ORD0250  19-02-25     Smartphone  Electronics    500         4
#
# ...

# %%
data.loc['Emily Johnson','Date'].reset_index().sort_values('Date').reset_index().drop(columns='index')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 data.loc['Emily Johnson','Date'].reset_index().sort_values('Date').reset_index().drop(columns='index')
#
# File c:\Users\TOGRUL\anaconda3\Lib\site-packages\pandas\core\indexing.py:1183, in _LocationIndexer.__getitem__(self, key)
#    1181     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182     if self._is_scalar_access(key):
# -> 1183         return self.obj._get_value(*key, takeable=self._takeable)
#    1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#
# File c:\Users\TOGRUL\anaconda3\Lib\site-packages\pandas\core\frame.py:4221, in DataFrame._get_value(self, index, col, takeable)
#    4215 engine = self.index._engine
#    4217 if not isinstance(self.index, MultiIndex):
# ...

# %%
data.set_index('Customer Name',inplace=True)

# %%
a=data[['Customer Name','Date']][data['Customer Name']=='Emily Johnson'].reset_index()
a.drop(columns='index',inplace=True)
a.rename(columns={'Customer Name':'Müştəri','Date':'Tarix'},inplace=True)
a
# Out:
#           Müştəri     Tarix
# 0   Emily Johnson  20-03-25
# 1   Emily Johnson  12-03-25
# 2   Emily Johnson  10-02-25
# 3   Emily Johnson  26-03-25
# 4   Emily Johnson  24-03-25
# 5   Emily Johnson  13-02-25
# 6   Emily Johnson  10-03-25
# 7   Emily Johnson  20-02-25
# 8   Emily Johnson  09-03-25
# 9   Emily Johnson  24-03-25
# 10  Emily Johnson  16-02-25
# 11  Emily Johnson  23-02-25
# 12  Emily Johnson  23-03-25
# 13  Emily Johnson  26-02-25
# 14  Emily Johnson  23-02-25
# 15  Emily Johnson  06-02-25
# 16  Emily Johnson  22-02-25
# 17  Emily Johnson  06-02-25
# 18  Emily Johnson  18-02-25
# 19  Emily Johnson  28-02-25
# 20  Emily Johnson  08-03-25
# 21  Emily Johnson  19-02-25

# %%
first_5_order_in_new_york=(
data[['Customer Location','Date']][data['Customer Location']=='New York'].
sort_values('Date').
reset_index().
drop(columns='index').
rename(columns={'Customer Location':'Məkan','Date':'Tarix'})
)
first_5_order_in_new_york.index=range(1,len(b)+1)
first_5_order_in_new_york.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 8
#       1 first_5_order_in_new_york=(
#       2 data[['Customer Location','Date']][data['Customer Location']=='New York'].
#       3 sort_values('Date').
#    (...)
#       6 rename(columns={'Customer Location':'Məkan','Date':'Tarix'})
#       7 )
# ----> 8 first_5_order_in_new_york.index=range(1,len(b)+1)
#       9 first_5_order_in_new_york.head(5)
#
# NameError: name 'b' is not defined

# %%
data

# %%
data.groupby('Customer Name').agg({'Total Sales':'min'}).sort_values('Total Sales').reset_index()

# %%
data

# %%
data.groupby(['Category','Payment Method']).agg({'Category':'count','Total Sales':['mean','min','max']})

# %%
data
# Out:
#               Order ID     Tarix         Məhsul   Kateqoriya  Price  Quantity  \
# Customer Name
# Emma Clark     ORD0001  14-03-25  Running Shoes     Footwear     60         3
# Emily Johnson  ORD0002  20-03-25     Headphones  Electronics    100         4
# John Doe       ORD0003  15-02-25  Running Shoes     Footwear     60         2
# Olivia Wilson  ORD0004  19-02-25  Running Shoes     Footwear     60         3
# Emma Clark     ORD0005  10-03-25     Smartwatch  Electronics    150         3
# ...                ...       ...            ...          ...    ...       ...
# Daniel Harris  ORD0246  17-03-25        T-Shirt     Clothing     20         2
# Sophia Miller  ORD0247  30-03-25          Jeans     Clothing     40         1
# Chris White    ORD0248  05-03-25        T-Shirt     Clothing     20         2
# Emily Johnson  ORD0249  08-03-25     Smartwatch  Electronics    150         3
# Emily Johnson  ORD0250  19-02-25     Smartphone  Electronics    500         4
#
# ...

# %%
data.pivot_table(index='Customer Name',columns='Product',values='Total Sales',aggfunc='sum')
# Out:
# Product         Book  Headphones  Jeans   Laptop  Refrigerator  Running Shoes  \
# Customer Name
# Chris White     75.0       600.0   80.0   2400.0        6000.0          480.0
# Daniel Harris  135.0      1500.0  480.0   7200.0        7200.0            NaN
# David Lee      285.0       600.0  280.0      NaN       14400.0          360.0
# Emily Johnson   15.0       900.0  200.0   4800.0        4800.0          360.0
# Emma Clark      90.0       500.0    NaN   9600.0        3600.0         1200.0
# Jane Smith     105.0       800.0  240.0  12800.0        9600.0          660.0
# John Doe        90.0       700.0  440.0   7200.0       10800.0          120.0
# Michael Brown   75.0       900.0  440.0   6400.0           NaN          300.0
# Olivia Wilson   90.0       500.0  160.0   8000.0       14400.0          540.0
# Sophia Miller   75.0       300.0  160.0      NaN        7200.0          300.0
#
# Product        Smartphone  Smartwatch  T-Shirt  Washing Machine
# Customer Name
# ...

# %%
data[data.isnull().any(axis=1)]

# %%
data.isna().values.any()
# Out:
# False

# %%
data.isna().any(axis=1)
# Out:
# Customer Name
# Emma Clark       False
# Emily Johnson    False
# John Doe         False
# Olivia Wilson    False
# Emma Clark       False
#                  ...
# Daniel Harris    False
# Sophia Miller    False
# Chris White      False
# Emily Johnson    False
# Emily Johnson    False
# Length: 250, dtype: bool

# %%
data.isnull().sum()
# Out:
# Order ID             0
# Tarix                0
# Məhsul               0
# Kateqoriya           0
# Price                0
# Quantity             0
# Total Sales          0
# Customer Location    0
# dtype: int64

# %%
data.sample(10)
# Out:
#               Order ID     Tarix           Məhsul       Kateqoriya  Price  \
# Customer Name
# Chris White    ORD0158  24-02-25           Laptop      Electronics    800
# David Lee      ORD0223  24-03-25            Jeans         Clothing     40
# David Lee      ORD0011  17-02-25             Book            Books     15
# Chris White    ORD0067  31-03-25       Headphones      Electronics    100
# Emma Clark     ORD0232  14-03-25     Refrigerator  Home Appliances   1200
# Jane Smith     ORD0076  24-02-25  Washing Machine  Home Appliances    600
# John Doe       ORD0141  21-03-25       Smartphone      Electronics    500
# Emma Clark     ORD0023  23-02-25             Book            Books     15
# David Lee      ORD0113  19-03-25             Book            Books     15
# Emma Clark     ORD0111  31-03-25           Laptop      Electronics    800
#
#                Quantity  Total Sales Customer Location
# Customer Name
# Chris White           3         2400             Miami
# ...

# %%
data.shape
# Out:
# (250, 8)
